# %% [markdown]
# # Transfer Trumans To AMASS Format

# %%
# !python ./scripts/data_process/convert_gimo_to_amass.py

# %% [markdown]
# # Split Motion

# %%
# !python ./scripts/data_process/gimo_motion_split.py

# %% [markdown]
# # Convert to PKL

# %%
# !python ./scripts/data_process/convert_amass_data.py \
  --path ./data/GIMO_Motion_Processed/gimo_motion_inference \
  --debug \
  --upright_start\
  --save_path ./data/gimo_motion_inference.pkl
