# %% [markdown]
# # Y-->Z axil Transform

# %%
# !python ./scripts/data_process/gimo_scene_axil_transfer.py

# %% [markdown]
# # Remove Floor

# %%
# !python ./scripts/data_process/gimo_scene_floor_process.py
